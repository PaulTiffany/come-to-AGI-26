# %% [markdown]
# # Working Python Example

# %% [markdown]
# **Learning objective.** Read and reason about a small working Python script.

# %% [markdown]
# ## Original code
#
# The snippet below is the code that ran.

# %%
"""Executable evidence for the exact discrete shadow-charge identity."""

from compitum.regret_lab.belief_action_pricing import (
    action_shadow_charge,
    unit_marginal_prices,
)
from compitum.regret_lab.belief_bellman import BellmanOracle
from compitum.regret_lab.belief_regime import GRID_UNIT

remaining_steps = 5
budget = 10.0
belief = 0.5
num_units = 8
oracle = BellmanOracle()

unit_prices = unit_marginal_prices(
    oracle,
    remaining_steps,
    budget,
    belief,
    num_units,
)
charge = action_shadow_charge(
    oracle,
    remaining_steps,
    budget,
    belief,
    num_units * GRID_UNIT,
)
telescoping_sum = sum(unit_prices)

assert len(unit_prices) == num_units
assert abs(telescoping_sum - charge) <= 1e-9

print(f"unit_prices={[round(value, 6) for value in unit_prices]}")
print(f"telescoping_sum={telescoping_sum:.6f}")
print(f"action_shadow_charge={charge:.6f}")
print("PASS")

# %% [markdown]
# ## Code map
#
# This file was treated as generic Python. Here is what the AST scanner observed without executing the source.
#
# **Imports**
# - `compitum.regret_lab.belief_action_pricing`
# - `compitum.regret_lab.belief_bellman`
# - `compitum.regret_lab.belief_regime`
#
# **Functions**
# - (none)
#
# **Classes**
# - (none)
#
# **Entrypoint**: this file has no `if __name__ == "__main__":` guard.
#
# **Top-level statements**: 18
#
# ## What to inspect first
#
# 1. Skim the imports above to set expectations about runtime dependencies and the import-policy result.
# 2. Read functions and classes in declaration order; the AST scanner lists them as they appear in the source.
# 3. If an entrypoint is present, jump to it to see what runs on direct execution.
# 4. Compare the execution-trace section to what the entrypoint would have produced; mismatches are the most useful starting points.

# %% [markdown]
# ## Execution trace
#
# - status: **succeeded**
# - exit code: `0`
# - timed out: `False`
# - duration (s): `0.204`
#
# Captured stdout:
#
# ```
# unit_prices=[0.769273, 0.141392, 0.444042, 0.4831, 0.5169, 0.6177, 0.605806, 0.534994]
# telescoping_sum=4.113207
# action_shadow_charge=4.113207
# PASS
# ```

# %% [markdown]
# ## Validation

# %%
# Validation: the script ran to completion without raising.
print("validation: generic_python OK")

# %% [markdown]
# ## Exercise
#
# Modify one line of the script and predict the effect.

# %% [markdown]
# ## Selected answer
#
# Any change that keeps the script runnable and produces a different but explainable result is acceptable.

# %% [markdown]
# ## Compilation Control Board (v1)
#
# | Check | Status |
# |---|---|
# | Source executed | [PASS] |
# | Import policy | [PASS] |
# | AI assistance | [NONE] |
# | Concept | Working Python Example (`generic_python`) - heuristic |
# | Allowed imports used | `compitum` |
# | Source SHA-256 (12) | `abee4e7b437c` |
# | Signed at | `2026-07-24T10:35:26.941476+00:00` |
#
# _See the sibling `.certificate.json` for the machine-readable pass/fail summary including notebook verification, and the `.audit.json` for the full provenance log._
